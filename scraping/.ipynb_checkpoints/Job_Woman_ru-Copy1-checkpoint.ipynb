# %% [markdown]
# https://www.woman.ru/psycho/career/forum/?sort=new

# %%
# pip install bs

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from tqdm.notebook import tqdm
import re

df = pd.DataFrame(columns=['text'])
df
# Out:
# Empty DataFrame
# Columns: [text]
# Index: []

# %%
url = 'https://www.woman.ru/psycho/career/forum/?sort=new'

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
html = response.text

# %%
# bs = BeautifulSoup(response.text,"lxml")
# print(bs)

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import requests
import json

def get_html(url):
    response = requests.get(url)
    return response.text

def get_all_links(html):
    soup = BeautifulSoup(html, features="html.parser")
    links = []
    tds = soup.find_all('div', {'class': 'page__content'})
    for td in tds:
        p = td.find_all('ul', {'class': 'list__container'})
        for i in p:
            q = i.find_all('li', {'class': "list-item"})
            for l in q:
                links.append(l.a['href'])
    return links

# def get_all_links_on_page(html, link):
#     soup = BeautifulSoup(html, features="html.parser")
#     tds = soup.find_all('tr')
#     for td in tds:
#         i = td.find('td', {'class':'td-block'})
#         if i != None:
#             return(i.find_all('a')[-1].text)
    
def get_links(html, link):
    soup = BeautifulSoup(html, features="html.parser")
    links = []
    tds = soup.find_all('li', {'class':'ipsPagination_page'})
    for td in tds:
        p = td.find_all('a')
        for q in p:
            if link in q['href']:
                links.append(q['href'])
    if len(links) == 0:
        return [link]
    return sorted(list(set(links)))

def get_all_links_one_theme(html):
    soup = BeautifulSoup(html, features="html.parser")
    links = []
    tds = soup.find_all('h4', {'class':'ipsDataItem_title ipsType_break'})
    for td in tds:
        p = td.find_all('a')
        for q in p:
            links.append(q['href'])
    return links

def get_page_data(html):
    soup = BeautifulSoup(urlopen(str(html.encode('utf-8'))[2:-1]), features="html.parser")

    # user
    tds = soup.find_all('div', {'class':"card__container"})
    users = []
    for td in tds:
        p = td.find_all('div', {'class':"user__maindata"})
        for q in p:
            u = q.find_all('div', {'class':"user__name"})
            for i in u:
                users.append(i.text)
#     print(users)


    # time
    tds = soup.find_all('div', {'class':"card__container"})
    times = []
    for td in tds:
        if td.find_all('div', {'class':"card__topic-data"}) == []:
            times.append(td.find('div', {'class':"card__message-data"}).find('time').text)
        else:
            times.append(td.find('div', {'class':"card__topic-data"}).find('time').text)
#     print(times)


    # text
    tds = soup.find_all('div', {'class':'card__text'})
    tex = []
    for td in tds: 
        p = td.find_all('p', {'class': 'card__comment'})
        for i in p:
            tex.append(i.text)
#     print(tex)
    

    # quote
    tds = soup.find_all('div', {'class':'card__text'})
    temp = []
    for td in tds: 
        q = td.find('p', {'class':'quote__text'})
        if q != None:
            temp.append(q.text)
        else:
            temp.append('')
#     print(temp)

    data = ({'user': users,                    
             'time': times,      
             'text': tex,            
             'quote': temp,          
             'topic': ['Job'] * len(users)
            })          
    return users, times, tex, temp, ['Job'] * len(users)#data

def page_content(all_links, table):
    for link in tqdm(all_links):
        link = 'https://www.woman.ru' + link
        print(link)
        us, ti, te, tem, l = get_page_data(link)
        for i in range(len(us)):
            if i > 5:
                break
            users.append(us[i])
            times.append(ti[i])
            tex.append(te[i])
            temp.append(tem[i])
            labels.append(l[i])
#         table.append(data)
#     links = get_links(get_html(all_links), all_links)
#     for l in links:
#         all_links_one_theme = get_all_links_one_theme(get_html(l))
#         for t in tqdm(all_links_one_theme):        
#             page = get_links(get_html(t), t)
#             for p in page:
#                 print(p)
#                 data = get_page_data(all_links)
#                 table.append(data)

table = pd.DataFrame(columns={'users', 'times', 'text', 'quote', 'topic'})
users = []
times = []
tex = []
temp = []
labels = []
    
url = 'https://www.woman.ru/psycho/career/forum/?sort=new'
all_links = get_all_links(get_html(url))
page_content(all_links, table)

for i in tqdm(range(2, 11)):
    url = 'https://www.woman.ru/psycho/career/forum/' + str(i) + '/?sort=new'
    all_links = get_all_links(get_html(url))
    page_content(all_links, table)
    
table.loc[:, 'users'] = users
table.loc[:, 'times'] = times
table.loc[:, 'text'] = tex
table.loc[:, 'quote'] = temp
table.loc[:, 'topic'] = labels
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# https://www.woman.ru/psycho/career/thread/5842828/
# https://www.woman.ru/psycho/career/thread/5842818/
# https://www.woman.ru/psycho/career/thread/5842775/
# https://www.woman.ru/psycho/career/thread/5842693/
# https://www.woman.ru/psycho/career/thread/5842668/
# https://www.woman.ru/psycho/career/thread/5842579/
# https://www.woman.ru/psycho/career/thread/5842575/
# https://www.woman.ru/psycho/career/thread/5842466/
# https://www.woman.ru/psycho/career/thread/5842386/
# https://www.woman.ru/psycho/career/thread/5842376/
# https://www.woman.ru/psycho/career/thread/5842322/
# https://www.woman.ru/psycho/career/thread/5842281/
# https://www.woman.ru/psycho/career/thread/5842221/
# https://www.woman.ru/psycho/career/thread/5842071/
# https://www.woman.ru/psycho/career/thread/5842047/
# https://www.woman.ru/psycho/career/thread/5842034/
# https://www.woman.ru/psycho/career/thread/5841646/
# https://www.woman.ru/psycho/career/thread/5841644/
# https://www.woman.ru/psycho/career/thread/5841511/
# https://www.woman.ru/psycho/career/thread/5841502/
# https://www.woman.ru/psycho/career/thread/5841475/
# https://www.woman.ru/psycho/career/thread/5841457/
# https://www.woman.ru/psycho/career/thread/5841435/
# https://www.woman.ru/psycho/career/thread/5841384/
# https://www.woman.ru/psycho/career/thread/5841350/
# https://www.woman.ru/psycho/career/thread/5841345/
# https://www.woman.ru/psycho/career/thread/5841334/
# https://www.woman.ru/psycho/career/thread/5841322/
# https://www.woman.ru/psycho/career/thread/5841312/
# https://www.woman.ru/psycho/career/thread/5841150/
# https://www.woman.ru/psycho/career/thread/5841143/
# https://www.woman.ru/psycho/career/thread/5841099/
# https://www.woman.ru/psycho/career/thread/5841058/
# https://www.woman.ru/psycho/career/thread/5841056/
# https://www.woman.ru/psycho/career/thread/5841007/
# https://www.woman.ru/psycho/career/thread/5840846/
# https://www.woman.ru/psycho/career/thread/5840750/
# https://www.woman.ru/psycho/career/thread/5840648/
# https://www.woman.ru/psycho/career/thread/5840619/
# https://www.woman.ru/psycho/career/thread/5840616/
# https://www.woman.ru/psycho/career/thread/5840606/
# https://www.woman.ru/psycho/career/thread/5840524/
# https://www.woman.ru/psycho/career/thread/5840483/
# https://www.woman.ru/psycho/career/thread/5840456/
# https://www.woman.ru/psycho/career/thread/5840388/
# https://www.woman.ru/psycho/career/thread/5840371/
# https://www.woman.ru/psycho/career/thread/5840365/
# https://www.woman.ru/psycho/career/thread/5840307/
# https://www.woman.ru/psycho/career/thread/5840289/
# https://www.woman.ru/psycho/career/thread/5840287/
#   0%|          | 0/9 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Поговорить лично, почему д.о.ё.б.ы.в.а.е.т.с.я...
# 4     Был у мну знакомый, строитель, а я в то время ...
# ...                                                 ...
# 2614                                                NaN
# 2615                                                NaN
# 2616                                                NaN
# 2617                                                NaN
# 2618              Нет,не стоит уходить,даже не думайте!
#
# [2619 rows x 5 columns]

# %%
import re

# %%
def cle(time_str):
    if time_str.split()[0][:-1].isalpha():
        return '02 мая 2023'
    else:
        return ' '.join(time_str.split()[:-1])[:-1]

# %%
D.loc[:, 'times'] = D.times.apply(lambda x: cle(x))

# %%
D.loc[:, 'text'] = D.text.apply(lambda x: re.sub(r'[\n\t\r\xa0]', '', str(x)))

# %%
D.loc[:, 'quote'] = D.quote.apply(lambda x: re.sub(r'[\n\t\r\xa0]', '', str(x)))

# %%
D.loc[:, 'users'] = D.users.apply(lambda x: re.sub(r'[\n\t\r\xa0]', '', str(x)))

# %%
D
# Out:
#      topic                                               text        times  \
# 0      Job  Пришла после отличных выходных на работу, и с ...  02 мая 2023
# 1      Job  Поговорить лично, почему д.о.ё.б.ы.в.а.е.т.с.я...  02 мая 2023
# 2      Job  Был у мну знакомый, строитель, а я в то время ...  02 мая 2023
# 3      Job  он хочет чтобы я его во всем слушалась, как ра...  02 мая 2023
# 4      Job  у меня тоже ощущение было, что я с гопником об...  02 мая 2023
# ...    ...                                                ...          ...
# 2614   Job  Конечно уходите. Мужу объясните, что на форуме...     31 марта
# 2615   Job                                         Фантазёрка     31 марта
# 2616   Job  смотря какой муж, мы ж его не знаем. может он ...     31 марта
# 2617   Job              Нет,не стоит уходить,даже не думайте!     31 марта
# 2618   Job                                           Почему ?     31 марта
#
#                     users                                              quote
# 0                  Автор                                                 nan
# 1                     95                                                 nan
# 2      Великолепный Вася                                                 nan
# 3                  Гость   Поговорить лично, почему д.о.ё.б.ы.в.а.е.т.с.я...
# 4                  Гость   Был у мну знакомый, строитель, а я в то время ...
# ...                   ...                                                ...
# 2614               Гость                                                 nan
# 2615               Гость                                                 nan
# 2616                 🍉😽🍉                                                 nan
# 2617               Гость                                                 nan
# 2618               Гость               Нет,не стоит уходить,даже не думайте!
#
# [2619 rows x 5 columns]

# %%
D.to_csv('Job.csv', index=False)

# %%
D = pd.read_csv('Job.csv')
D
# Out:
#      topic                                               text        times  \
# 0      Job  Пришла после отличных выходных на работу, и с ...  02 мая 2023
# 1      Job  Поговорить лично, почему д.о.ё.б.ы.в.а.е.т.с.я...  02 мая 2023
# 2      Job  Был у мну знакомый, строитель, а я в то время ...  02 мая 2023
# 3      Job  он хочет чтобы я его во всем слушалась, как ра...  02 мая 2023
# 4      Job  у меня тоже ощущение было, что я с гопником об...  02 мая 2023
# ...    ...                                                ...          ...
# 2614   Job  Конечно уходите. Мужу объясните, что на форуме...     31 марта
# 2615   Job                                         Фантазёрка     31 марта
# 2616   Job  смотря какой муж, мы ж его не знаем. может он ...     31 марта
# 2617   Job              Нет,не стоит уходить,даже не думайте!     31 марта
# 2618   Job                                           Почему ?     31 марта
#
#                     users                                              quote
# 0                  Автор                                                 NaN
# 1                     95                                                 NaN
# 2      Великолепный Вася                                                 NaN
# 3                  Гость   Поговорить лично, почему д.о.ё.б.ы.в.а.е.т.с.я...
# 4                  Гость   Был у мну знакомый, строитель, а я в то время ...
# ...                   ...                                                ...
# 2614               Гость                                                 NaN
# 2615               Гость                                                 NaN
# 2616                 🍉😽🍉                                                 NaN
# 2617               Гость                                                 NaN
# 2618               Гость               Нет,не стоит уходить,даже не думайте!
#
# [2619 rows x 5 columns]

# %%
count = 0
for i in range(len(D)):
    count += len(D['user'][i].split())
print('Количество записей с одного сайта по одной теме:', count)
# Out:
# Количество записей с одного сайта по одной теме: 4567

# %%
import random
import numpy as np
ind = np.random.choice(len(D), 25, False)
ind
# Out:
# array([ 63, 113,  48,  70,  74,  17,  50,  29,   5, 116,  59,  10,   7,
#         23,  46,  79,  88,  43,  65, 115, 105, 114,  25,   0,  86])

# %%
X = []
for i in ind:
    X.append(np.random.choice(D['text'][i].split(sep=']'), 4, False))

# %%
X[24]
# Out:
# array(['[[\'Добрый день, ушла с работы в "никуда" из-за прессинга начальника. Но подставила коллегу с отпуском. Т. К заявление подписали без отработки. Теперь мучаюсь виной. Я же готова была 2 недели отработать, но на меня обозлились и сразу уволили. А почему-то мучаюсь виной я..... Просто ушла и все получается. Вина такая захлестнула, как будто преступление совершила. Помогите, вправьте мозги, прям выкарабкаться не могу((( #работа\'',
#        ", ['Спасибо, а выглядит с моей стороны, как полная безответственность. Из-за этого и мучаюсь, хотя оставаться означало подорвать психическое здоровье.'",
#        ", ['За две недели вам начальник негатива бы накидал до нервного срыва'",
#        ", ['Спасибо, но уже состоялось увольнение. Нехорошо получилось, теперь не знаю, как в себя прийти.. Не получается. Состояние кризиса сильного.'"],
#       dtype='<U1491')

# %%
2+2+1+2+1+3+3+2+3+3+1+0+3+1+1+1+1+4+3+0+2+2+0+0+3
# Out:
# 44

# %%
44/(100-25)
# Out:
# 0.5866666666666667

# %%
D = pd.read_csv('Job_Woman_ru.csv')
D
# Out:
#                                                   user  \
# 0    [' Просто человек ', ' МДшник на Вумене ', ' Г...
# 1        [' Автор ', ' Деловунка всклянь ', ' Гость ']
# 2    [' Ива ', ' Гость ', ' Гость ', ' Гость ', ' Г...
# 3                            [' Автор ', ' Подружка ']
# 4    [' Маруся ', ' Бухие бухи ', ' Гость ', ' Жужа ']
# ..                                                 ...
# 495     [' Victory ', ' Гость ', ' Гость ', ' Гость ']
# 496  [' Автор ', ' тёмным-тёмным утром ', ' Focos '...
# 497  [' Автор ', ' Гость ', ' Автор ', ' Гость ', '...
# 498  [' Ольга ', ' Гость ', ' Гость ', ' Лиля ', ' ...
# 499                  [' Гость ', ' Гость ', ' Гость ']
#
#                                                   time  \
# 0    [' Сегодня, 14:11 ', ' Сегодня, 14:19 ', ' Сег...
# 1    [' Сегодня, 14:08 ', ' Сегодня, 14:25 ', ' Сег...
# 2    [' Сегодня, 13:37 ', ' Сегодня, 13:57 ', ' Сег...
# 3             [' Сегодня, 13:06 ', ' Сегодня, 14:17 ']
# 4    [' Сегодня, 13:04 ', ' Сегодня, 13:19 ', ' Сег...
# ..                                                 ...
# 495  [' 02 марта, 12:17 ', ' 02 марта, 12:29 ', ' 0...
# 496  [' 02 марта, 11:46 ', ' 02 марта, 12:14 ', ' 0...
# 497  [' 02 марта, 11:43 ', ' 02 марта, 12:18 ', ' 0...
# 498  [' 02 марта, 09:52 ', ' 02 марта, 10:04 ', ' 0...
# 499  [' 02 марта, 08:40 ', ' 02 марта, 09:20 ', ' 0...
#
#                                                   text  \
# 0    ['Я понимаю, что я раздолбайка, бросила учёбу,...
# 1    ['Проведите в пример ваши сильные косяки в раб...
# 2    ['Работаю по образованию - юристом, первое тру...
# 3    ['Хочу устроится на работу но пять лет назад м...
# 4    ['Добрый день!Работаю в частной клинике, хозяи...
# ..                                                 ...
# 495  ['#образование\xa0#учеба\xa0#вуз', 'Одной из п...
# 496  ['У меня скучная работа, каждый день одно и то...
# 497  ['Сорбираюсь увольняться. Хотелось бы по согла...
# 498  ['У меня проблема с работой возникла. До декре...
# 499  ['хочу отпроситься с работы, чтобы поехать пос...
#
#                                                  quote  \
# 0    ['', '', '', '', '', '', '', '', '"""Умею монт...
# 1                                         ['', '', '']
# 2    ['', '', '🤔 Выглядит интересно ваша ситуация!🚚...
# 3                                             ['', '']
# 4                                     ['', '', '', '']
# ..                                                 ...
# 495                                   ['', '', '', '']
# 496  ['', '', '', 'Знаете как я обычно делал? Не нр...
# 497  ['', '', 'если не заплатили сразу, то уже и не...
# 498  ['', '', '', '', '', 'Я тоже искала долго рабо...
# 499                                       ['', '', '']
#
#                                                  topic
# 0    ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 1                                ['Job', 'Job', 'Job']
# 2           ['Job', 'Job', 'Job', 'Job', 'Job', 'Job']
# 3                                       ['Job', 'Job']
# 4                         ['Job', 'Job', 'Job', 'Job']
# ..                                                 ...
# 495                       ['Job', 'Job', 'Job', 'Job']
# 496  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 497  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 498  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 499                              ['Job', 'Job', 'Job']
#
# [500 rows x 5 columns]

# %%
count = 0
for i in range(len(D)):
    count += len(D['user'][i].split())
print('Количество записей с одного сайта по одной теме:', count)
# Out:
# Количество записей с одного сайта по одной теме: 20657

# %%
D = pd.read_csv('Job_woman_talks.csv')
D
# Out:
#                                                  user  \
# 0   ['\nRebbekka', '\nСерсея', '\nRebbekka', '\nСе...
# 1   ['\nAugustina', '\nAdelaida', '\nBrysnichka', ...
# 2   ['\nblondi', '\nСофия0107', '\nKirra', '\nAugu...
# 3   ['\nИринка Матвеева', '\nIn-greed', '\nPolly',...
# 4   ['\nLana Voronina', '\nВероника В', '\nSveta81...
# 5                ['\nikari', '\ncorenad', '\nlina.l']
# 6                              ['\nТатьяна Мидорина']
# 7                    ['\nwomantalks.ru', '\nСчастье']
# 19  ['\nОпубликовано: 22 авг 2016\n', '\nОпубликов...
# 20  ['\nОпубликовано: 6 апр 2016\n', '\nОпубликова...
# 21  ['\nОпубликовано: 26 окт 2016\n\t\t\t\n\t\t\t\...
# 22  ['\nОпубликовано: 4 фев 2016\n', '\nОпубликова...
# 23  ['\nОпубликовано: 17 июн 2016\n', '\nОпубликов...
# 24  ['\nОпубликовано: 10 ноя 2016\n', '\nОпубликов...
# 25  ['\nОпубликовано: 6 фев 2016\n', '\nОпубликова...
# 26  ['\nОпубликовано: 22 мар 2016\n', '\nОпубликов...
# 27                  ['\nОпубликовано: 12 июн 2016\n']
# 28  ['\nОпубликовано: 4 фев 2016\n', '\nОпубликова...
# 29                   ['\nОпубликовано: 4 фев 2016\n']
# 30  ['\nОпубликовано: 1 фев 2016\n', '\nОпубликова...
# 31  ['\nОпубликовано: 5 янв 2016\n', '\nОпубликова...
# 32  ['\nОпубликовано: 24 июл 2015\n', '\nОпубликов...
# 33  ['\nОпубликовано: 24 июл 2015\n', '\nОпубликов...
#
#                                                  text  \
# 0   ['\n\nДевочки, очень хочу научится делать перм...
# 1   ['\n\n\tкласс) интересен ваш опыт) но опять же...
# 2   ['\n\n\tДевчули, всем привет. Кто как зарабаты...
# 3   ['\n\n\tДавно хочу открыть какое-то свое дело,...
# 4   ['\n\n\tИдея, бизнес-план, стартовый капитал.\...
# 5   ['\n\n\t\xa0Есть возможность инвестировать в г...
# 6   ['\n\n\tУважаемые девушки, всех приветствую ! ...
# 7   ['\n\n\tКто имеет опыт ведения бизнеса с близк...
# 8   ['\n\n\tВсем добрый день! Интересует работа в ...
# 9   ['\n\n\tВсем привет! Может у кого есть оригина...
# 10  ['\n\n\tЗдравствуйте. Устраиваюсь на работу, в...
# 11  ['\n\n\tСейчас очень сложно найти работу молод...
# 12  ['\n\n\tВсем привет, продумываю разные вариант...
# 13  ['\n\n\tНедавно нашла новую работу, можно сказ...
# 14  ['\n\n\tЕсли бы перед вами стоял выбор: высока...
# 15  ['\n\n\tЯ бы выбрала любимое дело. Потому, что...
# 16  ['\n\n\tДевочки, готовы ли вы, ради достижения...
# 17  ['\n\n\tЯ молодая, красивая девушка 23 года, в...
# 18  ['\n\n\n\n\n\n\n\tСогласны, что нам каждый ден...
# 19  ['\n\n\tДевушки, кто по работе пользуется перс...
# 20  ['\n\n\t1,5 года работаю на нынешнем месте раб...
# 21  ['\n\n\tПривет! У меня есть интернет-магазин. ...
# 22  ['\n\n\tЗдравствуйте, девочки! Кому-нибудь при...
# 23  ['\n\nИщу эконом-вариант холодильной витрины д...
# 24  ['\n\n\tУчусь в университете, еще и подрабатыв...
# 25  ['\n\n\tЯ жду двоих малышей. И у меня есть хор...
# 26  ['\n\n\tЧто делать, если работа нравится и хор...
# 27  ['\n\n\tТолько для тех у кого есть свой блог и...
# 28  ['\n\n\tНесколько лет работаю в одной фирме и ...
# 29  ['\n\nЗдравствуйте, требуется организатор совм...
# 30  ['\n\n\tКак вы считаете, уместно ли получить р...
# 31  ['\n\r\n\tУстраиваюсь на работу в ВЕТЕРАН в Ме...
# 32  ['\nДевочки, у вас есть в коллективе такие люд...
# 33  ['\nЕсли бы женщинам не пришлось идти на работ...
#
#                                                 quote  \
# 0   ['', '', '', '', '', '', '', '', '', '', '', '...
# 1   ['', '', '', '', '', '', '', '', '', '\n\n\t\t...
# 2   ['', '', '', '', '', '\n\n\t\t\tСпособов зараб...
# 3   ['', '', '', '', '', '', '', '', '', '', '', '...
# 4   ['', '', '', '', '\n\n\t\t\tИдея, бизнес-план,...
# 5                                        ['', '', '']
# 6                                                ['']
# 7                                            ['', '']
# 8                                                ['']
# 9                            ['', '', '', '', '', '']
# 10                                       ['', '', '']
# 11  ['', '', '', '', '', '', '', '', '', '', '', '...
# 12                                   ['', '', '', '']
# 13  ['', '', '', '', '\n\n\t\t\tмне помог курс из ...
# 14  ['', '', '', '', '', '', '', '', '', '', '', '...
# 15                       ['', '', '', '', '', '', '']
# 16  ['', '', '', '', '', '', '', '', '', '', '', '...
# 17                                               ['']
# 18                               ['', '', '', '', '']
# 19                                       ['', '', '']
# 20  ['', '', '\n\n\t\t\t1,5 года работаю на нынешн...
# 21           ['', '', '', '', '', '', '', '', '', '']
# 22  ['', '\n\r\n\t\t\tЗдравствуйте, девочки! Кому-...
# 23                       ['', '', '', '', '', '', '']
# 24  ['', '', '\n\n\t\t\tФакт сдачи - вот что важно...
# 25  ['', '', '', '', '', '\n\n\t\t\tЯ жду двоих ма...
# 26  ['', '', '', '', '\n\n\t\t\tЯ бы попробовала е...
# 27                                               ['']
# 28                                   ['', '', '', '']
# 29                                               ['']
# 30                                   ['', '', '', '']
# 31                                           ['', '']
# 32                               ['', '', '', '', '']
# 33                           ['', '', '', '', '', '']
#
#                                                 topic
# 0   ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 1   ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 2   ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 3   ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 4   ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 5                               ['Job', 'Job', 'Job']
# 6                                             ['Job']
# 7                                      ['Job', 'Job']
# 8                                             ['Job']
# 9          ['Job', 'Job', 'Job', 'Job', 'Job', 'Job']
# 10                              ['Job', 'Job', 'Job']
# 11  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 12                       ['Job', 'Job', 'Job', 'Job']
# 13                ['Job', 'Job', 'Job', 'Job', 'Job']
# 14  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 15  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Job']
# 16  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 17                                            ['Job']
# 18                ['Job', 'Job', 'Job', 'Job', 'Job']
# 19                              ['Job', 'Job', 'Job']
# 20  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 21  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 22  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 23  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Job']
# 24  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 25  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 26  ['Job', 'Job', 'Job', 'Job', 'Job', 'Job', 'Jo...
# 27                                            ['Job']
# 28                       ['Job', 'Job', 'Job', 'Job']
# 29                                            ['Job']
# 30                       ['Job', 'Job', 'Job', 'Job']
# 31                                     ['Job', 'Job']
# 32                ['Job', 'Job', 'Job', 'Job', 'Job']
# 33         ['Job', 'Job', 'Job', 'Job', 'Job', 'Job']

# %%
count = 0
for i in range(len(D)):
    count += len(D['user'][i].split())
print('Количество записей с одного сайта по одной теме:', count)
# Out:
# Количество записей с одного сайта по одной теме: 382
