# %% [markdown]
# https://www.woman.ru/rest/travel/forum/?sort=new#topic_26

# %%
# pip install bs

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from tqdm.notebook import tqdm
import re

df = pd.DataFrame(columns=['text'])
df
# Out:
# Empty DataFrame
# Columns: [text]
# Index: []

# %%
url = 'https://www.woman.ru/rest/travel/thread/5818807/'

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
html = response.text

# %%
# bs = BeautifulSoup(response.text,"lxml")
# print(bs)

# %%
url = 'https://www.woman.ru/rest/travel/forum/?sort=new#topic_26'

# %%
def get_all_links(html):
    soup = BeautifulSoup(html, features="html.parser")
    links = []
    tds = soup.find_all('div', {'class': 'page__content'})
    for td in tds:
        p = td.find_all('ul', {'class': 'list__container'})
        for i in p:
            q = i.find_all('li', {'class': "list-item"})
            for l in q:
                links.append(l.a['href'])
    return links
get_all_links(get_html(url))
# Out:
# ['/rest/travel/thread/5819906/',
#  '/rest/travel/thread/5818807/',
#  '/rest/travel/thread/5818802/',
#  '/rest/travel/thread/5818793/',
#  '/rest/travel/thread/5818587/',
#  '/rest/travel/thread/5818580/',
#  '/rest/travel/thread/5818509/',
#  '/rest/travel/thread/5818503/',
#  '/rest/travel/thread/5817400/',
#  '/rest/travel/thread/5816862/',
#  '/rest/travel/thread/5816492/',
#  '/rest/travel/thread/5816016/',
#  '/rest/travel/thread/5815465/',
#  '/rest/travel/thread/5815313/',
#  '/rest/travel/thread/5815151/',
#  '/rest/travel/thread/5814546/',
#  '/rest/travel/thread/5814297/',
#  '/rest/travel/thread/5814145/',
#  '/rest/travel/thread/5814041/',
#  '/rest/travel/thread/5813937/',
#  '/rest/travel/thread/5813746/',
#  '/rest/travel/thread/5813543/',
#  '/rest/travel/thread/5813539/',
#  '/rest/travel/thread/5813515/',
#  '/rest/travel/thread/5813402/',
#  '/rest/travel/thread/5812794/',
#  '/rest/travel/thread/5812706/',
#  '/rest/travel/thread/5812119/',
#  '/rest/travel/thread/5811843/',
#  '/rest/travel/thread/5811706/',
#  '/rest/travel/thread/5811542/',
#  '/rest/travel/thread/5811434/',
#  '/rest/travel/thread/5810649/',
#  '/rest/travel/thread/5810277/',
#  '/rest/travel/thread/5809975/',
#  '/rest/travel/thread/5809846/',
#  '/rest/travel/thread/5809422/',
#  '/rest/travel/thread/5809189/',
#  '/rest/travel/thread/5808749/',
#  '/rest/travel/thread/5808729/',
#  '/rest/travel/thread/5808674/',
#  '/rest/travel/thread/5808356/',
#  '/rest/travel/thread/5807996/',
#  '/rest/travel/thread/5807307/',
#  '/rest/travel/thread/5806903/',
#  '/rest/travel/thread/5806861/',
#  '/rest/travel/thread/5806593/',
#  '/rest/travel/thread/5806427/',
#  '/rest/travel/thread/5806251/',
#  '/rest/travel/thread/5805997/']

# %%
def get_page_data(html):
    soup = BeautifulSoup(urlopen(str(url.encode('utf-8'))[2:-1]), features="html.parser")

    # user
    tds = soup.find_all('div', {'class':"card__container"})
    users = []
    for td in tds:
        p = td.find_all('div', {'class':"user__maindata"})
        for q in p:
            u = q.find_all('div', {'class':"user__name"})
            for i in u:
                users.append(i.text)
    print(users)


    # time
    tds = soup.find_all('div', {'class':"card__container"})
    times = []
    for td in tds:
        if td.find_all('div', {'class':"card__topic-data"}) == []:
            times.append(td.find('div', {'class':"card__message-data"}).find('time').text)
        else:
            times.append(td.find('div', {'class':"card__topic-data"}).find('time').text)
    print(times)


    # text
    tds = soup.find_all('div', {'class':'card__text'})
    tex = []
    for td in tds: 
        p = td.find_all('p', {'class': 'card__comment'})
        for i in p:
            tex.append(i.text)
    print(tex)
    

    # quote
    tds = soup.find_all('div', {'class':'card__text'})
    temp = []
    for td in tds: 
        q = td.find('p', {'class':'quote__text'})
        if q != None:
            temp.append(q.text)
        else:
            temp.append('')
    print(temp)

    data = ({'user': users,                    
             'time': times,      
             'text': tex,            
             'quote': temp,          
             'topic': ['Depression'] * len(users)
            })          
    return data
get_page_data(get_html(url))
# Out:
# [' Автор ', ' Засранец ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Засранец ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Автоответчик ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Засранец ', ' Гость ', ' Засранец ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ', ' Гость ']
# [' 25 марта, 16:22 ', ' 25 марта, 16:56 ', ' 25 марта, 16:57 ', ' 25 марта, 16:58 ', ' 25 марта, 16:59 ', ' 25 марта, 16:59 ', ' 25 марта, 17:00 ', ' 25 марта, 17:00 ', ' 25 марта, 17:01 ', ' 25 марта, 17:03 ', ' 25 марта, 17:03 ', ' 25 марта, 17:04 ', ' 25 марта, 17:04 ', ' 25 марта, 17:05 ', ' 25 марта, 17:06 ', ' 25 марта, 17:06 ', ' 25 марта, 17:07 ', ' 25 марта, 17:08 ', ' 25 марта, 17:08 ', ' 25 марта, 17:09 ', ' 25 марта, 17:09 ', ' 25 марта, 17:10 ', ' 25 марта, 17:12 ', ' 25 марта, 17:12 ', ' 25 марта, 17:13 ', ' 25 марта, 17:14 ', ' 25 марта, 17:14 ', ' 25 марта, 17:16 ', ' 25 марта, 17:17 ', ' 25 марта, 17:18 ', ' 25 марта, 17:19 ', ' 25 марта, 17:22 ', ' 25 марта, 17:24 ', ' 25 марта, 17:24 ', ' 25 марта, 17:25 ', ' 25 марта, 17:26 ', ' 25 марта, 17:27 ', ' 25 марта, 17:28 ', ' 25 марта, 17:28 ', ' 25 марта, 17:29 ', ' 25 марта, 17:30 ', ' 25 марта, 17:31 ', ' 25 марта, 17:31 ', ' 25 марта, 17:31 ', ' 25 марта, 17:33 ', ' 25 марта, 17:34 ', ' 25 марта, 17:34 ', ' 25 марта, 17:35 ', ' 25 марта, 17:35 ', ' 25 марта, 17:36 ', ' 25 марта, 17:36 ']
# ['Научный руководитель настаивает на стажировке во Франции. Честно говоря, не очень люблю эту страну и не хочу бросать нынешнюю работу. Так получилось, что диссертация - хобби, никак не связанное с зарабатыванием денег... Как тактично отказаться оо поездки в Париж, чтобы не обидеть научника?', 'О , бы сгонялТакая возможность. Воспользуйся !', 'что за ВУЗ, мать?', 'И что там хорошего?', 'Не вуз, папаша, а академический институт. Но тебя туда не возьмут расслабь булки)', 'Люди грубые
', 'То есть ответить на вопрос нормально Вас в академии не научили? Профессия какая? Это не только меня интересует, наверняка.', 'Деточка, я знаю уж куда побольше Вашего...', 'Я поняла, что вам нечего послаетовать по существу. Вместо совето - допрос и зависть. У тебя, мать, самой какие "столичные образования"? Выкладывай давай)', 'Много знать и не надо, от Франции скоро пепел останется. Все горит и пылает, люди недовольны и это только начало.', 'Сегодня, 17:18#29Гость[274534019]Сегодня, 17:00#6Гостьчто за ВУЗ, мать?Кстати, баклан, вуз пишется строчными буквами. "Два" тебе за имбецильность)Приятная ВЫ девушка, и главное, Франция Вас ждёт. А ВЫ в курсе, что иногда даже профессора могут ошибаться? Такое со всеми живыми людьми происходит, даже с ученой степенью. Каждому будете говорить про "имбецильность"? С Вами и пошутить нельзя. Выходит, что социальный интеллект у Вас недоразвит. Что ж такое с Вами происходит?', '', 'Причем тут зависть? Вы вообще зациклены на ней. Я спросила, что з ...
# {'user': [' Автор ',
#   ' Засранец ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Засранец ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Автоответчик ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Засранец ',
#   ' Гость ',
#   ' Засранец ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость ',
#   ' Гость '],
#  'time': [' 25 марта, 16:22 ',
#   ' 25 марта, 16:56 ',
#   ' 25 марта, 16:57 ',
#   ' 25 марта, 16:58 ',
#   ' 25 марта, 16:59 ',
#   ' 25 марта, 16:59 ',
#   ' 25 марта, 17:00 ',
#   ' 25 марта, 17:00 ',
#   ' 25 марта, 17:01 ',
#   ' 25 марта, 17:03 ',
#   ' 25 марта, 17:03 ',
#   ' 25 марта, 17:04 ',
#   ' 25 марта, 17:04 ',
#   ' 25 марта, 17:05 ',
#   ' 25 марта, 17:06 ',
#   ' 25 марта, 17:06 ',
#   ' 25 марта, 17:07 ',
#   ' 25 марта, 17:08 ',
#   ' 25 марта, 17:08 ',
#   ' 25 марта, 17:09 ',
#   ' 25 марта, 17:09 ',
#   ' 25 марта, 17:10 ',
#   ' 25 марта, 17:12 ',
#   ' 25 марта, 17:12 ',
#   ' 25 марта, 17:13 ',
#   ' 25 марта, 17:14 ',
#   ' 25 марта, 17:14 ',
#   ' 25 марта, 17:16 ',
#   ' 25 марта, 17:17 ',
#   ' 25 марта, 17:18 ',
#   ' 25 марта, 17:19 ',
#   ' 25 марта, 17:22 ',
#   ' 25 марта, 17:24 ',
#   ' 25 марта, 17:24 ',
#   ' 25 марта, 17:25 ',
#   ' 25 марта, 17:26 ',
#   ' 25 марта, 17:27 ',
#   ' 25 марта, 17:28 ',
#   ' 25 марта, 17:28 ',
#   ' 25 марта, 17:29 ',
#   ' 25 марта, 17:30 ',
#   ' 25 марта, 17:31 ',
#   ' 25 марта, 17:31 ',
#   ' 25 марта, 17:31 ',
#   ' 25 марта, 17:33 ',
#   ' 25 марта, 17:34 ',
#   ' 25 марта, 17:34 ',
#   ' 25 марта, 17:35 ',
#   ' 25 марта, 17:35 ',
#   ' 25 марта, 17:36 ',
#   ' 25 марта, 17:36 '],
#  'text': ['Научный руководитель настаивает на стажировке во Франции. Честно говоря, не очень люблю эту страну и не хочу бросать нынешнюю работу. Так получилось, что диссертация - хобби, никак не связанное с зарабатыванием денег... Как тактично отказаться оо поездки в Париж, чтобы не обидеть научника?',
#   'О , бы сгонялТакая возможность. Воспользуйся !',
#   'что за ВУЗ, мать?',
#   'И что там хорошего?',
#   'Не вуз, папаша, а академический институт. Но тебя туда не возьмут расслабь булки)',
#   'Люди грубые там.',
#   'Кстати, баклан, вуз пишется строчными буквами. "Два" тебе за имбецильность)',
#   'Сменить обстановку,на время, никогда не вредно',
#   'Арабы и нигеры, я в курсе...(',
#   'И потерять работу тут?',
#   'Это все, что вы "знаете" о Франции? Даже не смешно...',
#   'Деточка, я знаю уж куда побольше Вашего...',
#   'почему , дама, Вы решили, что я мужчина и почему решили, что я собираюсь поступать, имея два высших столичных образования? То есть отвечать на вопросы просто и непринужденно Вам религия не дозволяет?',
#   'Я и белых имею в виду. Грубые и высокомерные.',
#   'Простите, что? Это с таким уровнем реакции на простые и юморные вопросы, Вы считаете себя хорошим и достойным будущим специалистом? У Вас дурно, милая, со стрессоустойчивостью. Как жить будете? Всё время при родителях?',
#   'Много знать и не надо, от Франции скоро пепел останется. Все горит и пылает, люди недовольны и это только начало.',
#   'Вам можно не возвращаться.',
#   'Да, грядут большие перемены во всём мире, Европу они тоже ждут, судя по всему...',
#   'Мамаша, я отзеркаливаю Ваше хамское обращение. У меня два высших образования (Москва) и степеоь кандидата наук. А Вы хамка и хабалка)',
#   'Согласна!',
#   'ничего от слова совсем',
#   'Плюс один!)',
#   'Перемены мягко сказано, большая ж о п а и не только Европе, мы с какого то дуру решили с западными интегрироваться на свою голову. Они идут ко дну как Титаник и нас с собой потащат.',
#   'Нет никакого хамства, учитывая, что я Вас не вижу, могу задать вопрос на короткой ноге. Особо Вы не отзеркалили, Вы именно отреагировали по-хабальски. Реагировать автор может как угодно, но так и проверяют автора на "вшивость". Учтите. И пользуйтесь ЧЮ. Ответили бы спокойно. Никто не хамил, не оскорблял Вас. А вот Вы себе это позволили. Так сколько Вам лет, что уже два высших?',
#   'Я бы не отказался, никогда не знаешь пригодится или нет. Впоследствии, при случае можно приврать с три короба и пристроить свою стажировку за полный курс обучения и тд и тп.',
#   'Останьтесь там навсегда и врите пока не надоест, что вы жертва путинского режима.',
#   'Напишите какие образования и профессия, где сейчас легко посылают на стажировку в Европу при нынешней ситуации. Простой человеческий интерес.',
#   'Ох, беда в том, что для этой "поездочки" мнн надо увольняться с работы, понимаете? Вернусь ромле мтажировеи, и что? Не факт, что работу вотбщр найду...',
#   'Гость[274534019]Сегодня, 16:59#4Гостьчто за ВУЗ, мать?Не вуз, папаша, а академический институт. Но тебя туда не возьмут расслабь булки)',
#   'Гость[274534019]Сегодня, 17:00#6Гостьчто за ВУЗ, мать?Кстати, баклан, вуз пишется строчными буквами. "Два" тебе за имбецильность).....ей слово "мать", а она кучу оскорблений ))))интеллигентка-таки!',
#   'Можете не напрягаться, статусной работы по любому найти не получится. Остается мытье унитазов или ботом на этом и многих других форумах.',
#   'М, при чем тут " статусная работа"?! Мне нужна посто работа.',
#   'Завидуй молча)',
#   'Прям "логика" "культурной" "высокоразвитой" дамы. О как! Ты ей слово, а в ответ оскорбления и унижения...Ну в добрый путь, как говорится!',
#   'Мы на "ТЫ " не переходили, да и чему завидовать? В своё время я была не только там...',
#   'То есть ответить на вопрос нормально Вас в академии не научили? Профессия какая? Это не только меня интересует, наверняка.',
#   'Постная или постоянная? Конкретней указывайте.',
#   'Чего?',
#   'Профессия не имеет значения там, без корочки тамошнего образования вы никто.',
#   'Судя по ответам м манере общения, боитесь потерять работу вахтёрши ?',
#   'Сегодня, 17:18#29Гость[274534019]Сегодня, 17:00#6Гостьчто за ВУЗ, мать?Кстати, баклан, вуз пишется строчными буквами. "Два" тебе за имбецильность)Приятная ВЫ девушка, и главное, Франция Вас ждёт. А ВЫ в курсе, что иногда даже профессора могут ошибаться? Такое со всеми живыми людьми происходит, даже с ученой степенью. Каждому будете говорить про "имбецильность"? С Вами и пошутить нельзя. Выходит, что социальный интеллект у Вас недоразвит. Что ж такое с Вами происходит?',
#   'И это всё из-за невинного слова "мать"))))Да как бы наша автор не выстрелила в кого при наличии оружия )))не удивлюсь!',
#   'Я поняла, что вам нечего послаетовать по существу. Вместо совето - допрос и зависть. У тебя, мать, самой какие "столичные образования"? Выкладывай давай)',
#   'Заметно 😂',
#   'Причем тут зависть? Вы вообще зациклены на ней. Я спросила, что за профессия? Почему я не могу узнать? Почему я обязана ВАМ что-то выкладывать, если Вы ничего о себе не говорите? Вам логику явно не преподавали...',
#   'Да-да, Запад загнивает, загнивает... и все никак не прекратит править миром. Вы, надо полагать, пишете из 1970-х советских годов? Или из 1920-х, тут возможны варианты.',
#   'Мать, "социальный интеллект" - это ересь. С тобрй все ясно)',
#   'Кстати, "мать" вообще не звучит оскорбительно.А вот Ваши дальнейшие посты перечитайте.',
#   'Тебе нечего посоветовать. Сиди и завидуй)',
#   'Вы такая высокоразвитая и образованная, что всё равно продолжаете вести диалог на ТЫ, хоть Вам и вынесли замечание. Ну-ну...Продолжайте',
#   'Ересь - это когда человека другого оскорбил, назвав имбецилом.'],
#  'quote': ['',
#   '',
#   '',
#   'О , бы сгонялТакая возможность. Воспользуйся !',
#   'что за ВУЗ, мать?',
#   '',
#   'что за ВУЗ, мать?',
#   'И что там хорошего?',
#   'Люди грубые там.',
#   'Сменить обстановку,на время, никогда не вредно',
#   'Арабы и нигеры, я в курсе...(',
#   'Это все, что вы "знаете" о Франции? Даже не смешно...',
#   'Не вуз, папаша, а академический институт. Но тебя туда не возьмут расслабь булки)',
#   'Арабы и нигеры, я в курсе...(',
#   'Кстати, баклан, вуз пишется строчными буквами. "Два" тебе за имбецильность)',
#   'Это все, что вы "знаете" о Франции? Даже не смешно...',
#   'Сменить обстановку,на время, никогда не вредно',
#   'Много знать и не надо, от Франции скоро пепел останется. Все горит и пылает, люди недовольны и это только начало.',
#   'почему , дама, Вы решили, что я мужчина и почему решили, что я собираюсь поступать, имея два высших столичных образования? То есть отвечать на вопросы просто и непринужденно Вам религия не дозволяет?',
#   'Я и белых имею в виду. Грубые и высокомерные.',
#   'И что там хорошего?',
#   'ничего от слова совсем',
#   'Да, грядут большие перемены во всём мире, Европу они тоже ждут, судя по всему...',
#   'Мамаша, я отзеркаливаю Ваше хамское обращение. У меня два высших образования (Москва) и степеоь кандидата наук. А Вы хамка и хабалка)',
#   '',
#   'Я бы не отказался, никогда не знаешь пригодится или нет. Впоследствии, при случае можно приврать с три короба и пристроить свою стажировку за полный курс обучения и тд и тп.',
#   '',
#   'Я бы не отказался, никогда не знаешь пригодится или нет. Впоследствии, при случае можно приврать с три короба и пристроить свою стажировку за полный курс обучения и тд и тп.',
#   '',
#   '',
#   'Ох, беда в том, что для этой "поездочки" мнн надо увольняться с работы, понимаете? Вернусь ромле мтажировеи, и что? Не факт, что работу вотбщр найду...',
#   'Можете не напрягаться, статусной работы по любому найти не получится. Остается мытье унитазов или ботом на этом и многих других форумах.',
#   'Напишите какие образования и профессия, где сейчас легко посылают на стажировку в Европу при нынешней ситуации. Простой человеческий интерес.',
#   'Гость[274534019]Сегодня, 17:00#6Гостьчто за ВУЗ, мать?Кстати, баклан, вуз пишется строчными буквами. "Два" тебе за имбецильность).....ей слово "мать", а она кучу оскорблений ))))интеллигентка-таки!',
#   'Завидуй молча)',
#   'Завидуй молча)',
#   'М, при чем тут " статусная работа"?! Мне нужна посто работа.',
#   'Вам можно не возвращаться.',
#   'То есть ответить на вопрос нормально Вас в академии не научили? Профессия какая? Это не только меня интересует, наверняка.',
#   'И потерять работу тут?',
#   '',
#   'Сегодня, 17:18#29Гость[274534019]Сегодня, 17:00#6Гостьчто за ВУЗ, мать?Кстати, баклан, вуз пишется строчными буквами. "Два" тебе за имбецильность)Приятная ВЫ девушка, и главное, Франция Вас ждёт. А ВЫ в курсе, что иногда даже профессора могут ошибаться? Такое со всеми живыми людьми происходит, даже с ученой степенью. Каждому будете говорить про "имбецильность"? С Вами и пошутить нельзя. Выходит, что социальный интеллект у Вас недоразвит. Что ж такое с Вами происходит?',
#   'То есть ответить на вопрос нормально Вас в академии не научили? Профессия какая? Это не только меня интересует, наверняка.',
#   'Деточка, я знаю уж куда побольше Вашего...',
#   'Я поняла, что вам нечего послаетовать по существу. Вместо совето - допрос и зависть. У тебя, мать, самой какие "столичные образования"? Выкладывай давай)',
#   'Много знать и не надо, от Франции скоро пепел останется. Все горит и пылает, люди недовольны и это только начало.',
#   'Сегодня, 17:18#29Гость[274534019]Сегодня, 17:00#6Гостьчто за ВУЗ, мать?Кстати, баклан, вуз пишется строчными буквами. "Два" тебе за имбецильность)Приятная ВЫ девушка, и главное, Франция Вас ждёт. А ВЫ в курсе, что иногда даже профессора могут ошибаться? Такое со всеми живыми людьми происходит, даже с ученой степенью. Каждому будете говорить про "имбецильность"? С Вами и пошутить нельзя. Выходит, что социальный интеллект у Вас недоразвит. Что ж такое с Вами происходит?',
#   '',
#   'Причем тут зависть? Вы вообще зациклены на ней. Я спросила, что за профессия? Почему я не могу узнать? Почему я обязана ВАМ что-то выкладывать, если Вы ничего о себе не говорите? Вам логику явно не преподавали...',
#   'Мать, "социальный интеллект" - это ересь. С тобрй все ясно)',
#   'Мать, "социальный интеллект" - это ересь. С тобрй все ясно)'],
#  'topic': ['Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression',
#   'Depression']}

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import requests
import json

def get_html(url):
    response = requests.get(url)
    return response.text

def get_all_links(html):
    soup = BeautifulSoup(html, features="html.parser")
    links = []
    tds = soup.find_all('div', {'class': 'page__content'})
    for td in tds:
        p = td.find_all('ul', {'class': 'list__container'})
        for i in p:
            q = i.find_all('li', {'class': "list-item"})
            for l in q:
                links.append(l.a['href'])
    return links

# def get_all_links_on_page(html, link):
#     soup = BeautifulSoup(html, features="html.parser")
#     tds = soup.find_all('tr')
#     for td in tds:
#         i = td.find('td', {'class':'td-block'})
#         if i != None:
#             return(i.find_all('a')[-1].text)
    
def get_links(html, link):
    soup = BeautifulSoup(html, features="html.parser")
    links = []
    tds = soup.find_all('li', {'class':'ipsPagination_page'})
    for td in tds:
        p = td.find_all('a')
        for q in p:
            if link in q['href']:
                links.append(q['href'])
    if len(links) == 0:
        return [link]
    return sorted(list(set(links)))

def get_all_links_one_theme(html):
    soup = BeautifulSoup(html, features="html.parser")
    links = []
    tds = soup.find_all('h4', {'class':'ipsDataItem_title ipsType_break'})
    for td in tds:
        p = td.find_all('a')
        for q in p:
            links.append(q['href'])
    return links

def get_page_data(html):
    soup = BeautifulSoup(urlopen(str(html.encode('utf-8'))[2:-1]), features="html.parser")

    # user
    tds = soup.find_all('div', {'class':"card__container"})
    users = []
    for td in tds:
        p = td.find_all('div', {'class':"user__maindata"})
        for q in p:
            u = q.find_all('div', {'class':"user__name"})
            for i in u:
                users.append(i.text)
#     print(users)


    # time
    tds = soup.find_all('div', {'class':"card__container"})
    times = []
    for td in tds:
        if td.find_all('div', {'class':"card__topic-data"}) == []:
            times.append(td.find('div', {'class':"card__message-data"}).find('time').text)
        else:
            times.append(td.find('div', {'class':"card__topic-data"}).find('time').text)
#     print(times)


    # text
    tds = soup.find_all('div', {'class':'card__text'})
    tex = []
    for td in tds: 
        p = td.find_all('p', {'class': 'card__comment'})
        for i in p:
            tex.append(i.text)
#     print(tex)
    

    # quote
    tds = soup.find_all('div', {'class':'card__text'})
    temp = []
    for td in tds: 
        q = td.find('p', {'class':'quote__text'})
        if q != None:
            temp.append(q.text)
        else:
            temp.append('')
#     print(temp)

    data = ({'user': users,                    
             'time': times,      
             'text': tex,            
             'quote': temp,          
             'topic': ['Travel'] * len(users)
            })          
    return data

def page_content(all_links, table):
    for link in tqdm(all_links):
        link = 'https://www.woman.ru' + link
        print(link)
        data = get_page_data(link)
        table.append(data)
#     links = get_links(get_html(all_links), all_links)
#     for l in links:
#         all_links_one_theme = get_all_links_one_theme(get_html(l))
#         for t in tqdm(all_links_one_theme):        
#             page = get_links(get_html(t), t)
#             for p in page:
#                 print(p)
#                 data = get_page_data(all_links)
#                 table.append(data)

table = []
    
url = 'https://www.woman.ru/rest/travel/forum/?sort=new#topic_26'
all_links = get_all_links(get_html(url))
page_content(all_links, table)

for i in tqdm(range(2, 21)):
    url = 'https://www.woman.ru/rest/travel/forum/' + str(i) + '/?sort=new'
    all_links = get_all_links(get_html(url))
    page_content(all_links, table)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# https://www.woman.ru/rest/travel/thread/5819960/
# https://www.woman.ru/rest/travel/thread/5818807/
# https://www.woman.ru/rest/travel/thread/5818802/
# https://www.woman.ru/rest/travel/thread/5818793/
# https://www.woman.ru/rest/travel/thread/5818587/
# https://www.woman.ru/rest/travel/thread/5818580/
# https://www.woman.ru/rest/travel/thread/5818509/
# https://www.woman.ru/rest/travel/thread/5818503/
# https://www.woman.ru/rest/travel/thread/5817400/
# https://www.woman.ru/rest/travel/thread/5816862/
# https://www.woman.ru/rest/travel/thread/5816492/
# https://www.woman.ru/rest/travel/thread/5816016/
# https://www.woman.ru/rest/travel/thread/5815465/
# https://www.woman.ru/rest/travel/thread/5815313/
# https://www.woman.ru/rest/travel/thread/5815151/
# https://www.woman.ru/rest/travel/thread/5814546/
# https://www.woman.ru/rest/travel/thread/5814297/
# https://www.woman.ru/rest/travel/thread/5814145/
# https://www.woman.ru/rest/travel/thread/5814041/
# https://www.woman.ru/rest/travel/thread/5813937/
# https://www.woman.ru/rest/travel/thread/5813746/
# https://www.woman.ru/rest/travel/thread/5813543/
# https://www.woman.ru/rest/travel/thread/5813539/
# https://www.woman.ru/rest/travel/thread/5813515/
# https://www.woman.ru/rest/travel/thread/5813402/
# https://www.woman.ru/rest/travel/thread/5812794/
# https://www.woman.ru/rest/travel/thread/5812706/
# https://www.woman.ru/rest/travel/thread/5812119/
# https://www.woman.ru/rest/travel/thread/5811843/
# https://www.woman.ru/rest/travel/thread/5811706/
# https://www.woman.ru/rest/travel/thread/5811542/
# https://www.woman.ru/rest/travel/thread/5811434/
# https://www.woman.ru/rest/travel/thread/5810649/
# https://www.woman.ru/rest/travel/thread/5810277/
# https://www.woman.ru/rest/travel/thread/5809975/
# https://www.woman.ru/rest/travel/thread/5809846/
# https://www.woman.ru/rest/travel/thread/5809422/
# https://www.woman.ru/rest/travel/thread/5809189/
# https://www.woman.ru/rest/travel/thread/5808749/
# https://www.woman.ru/rest/travel/thread/5808729/
# https://www.woman.ru/rest/travel/thread/5808674/
# https://www.woman.ru/rest/travel/thread/5808356/
# https://www.woman.ru/rest/travel/thread/5807996/
# https://www.woman.ru/rest/travel/thread/5807307/
# https://www.woman.ru/rest/travel/thread/5806903/
# https://www.woman.ru/rest/travel/thread/5806861/

# %%
pd.DataFrame(table).to_csv('Travel_Woman_ru.csv', index=False)

# %%
D = pd.read_csv('Travel_Woman_ru.csv')
D

# %%
count = 0
for i in range(len(D)):
    count += len(D['user'][i].split())
print('Количество записей с одного сайта по одной теме:', count)
