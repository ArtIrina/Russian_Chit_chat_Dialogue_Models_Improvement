# %% [markdown]
# https://www.travel.ru/community/

# %%
# pip install bs

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from tqdm.notebook import tqdm

df = pd.DataFrame(columns=['text'])
df
# Out:
# Empty DataFrame
# Columns: [text]
# Index: []

# %%
url = 'https://www.travel.ru/community/'

# %%
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
bs = BeautifulSoup(response.text,"lxml")
print(bs)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="ru-RU">
# <head>
# <!-- cutcut -->
# <title>Как сделать кудри утюжком - Волосы - Женский форум WomanTalks</title>
# <!--[if lt IE 9]>
# 			<link rel="stylesheet" type="text/css" href="https://womantalks.ru/uploads/css_built_1/5e61784858ad3c11f00b5706d12afe52_ie8.css.e1d5e41dbedaaaa7f2159105a3c3c54f.css">
# 		    <script src="//womantalks.ru/applications/core/interface/html5shiv/html5shiv.js"></script>
# 		<![endif]-->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="
#
# 	Кудри издавна считались особым элементом прически. Они вселяют невинность в образ, а также нежность и беззаботность. В некоторых случаях обольщения мужск..." name="description"/>
# <meta content="Как сделать кудри утюжком" property="og:title"/>
# <meta content="object" property="og:type"/>
# <meta content="https://womantalks.ru/topic/283-kak-sdelat-kudri-utyuzhkom/" property="og:url"/>
# <meta content="
#
# ...

# %%
# def class_(tag="div"):
#     return ({"class": "message", "style": "float: left; width: 99%; overflow: auto;"} if not tag.has_attr('quote') 
#            else {"class": "quote", "style": "width: 95%; overflow: auto;"})

# %%
# temp = []
# i = 0
# for h in bs.find_all("div", "message"):   #'div', 'message')
# #     print(h.find("div", "quote"))
# #     print(h)
# #     if i ==1:
# #         print(h.find())
# #     print()
    
#     if h.find("div", "quote") is not None:
#         temp.append(h.find("div", "quote"))#attr={"class":"message", "style":"float: left; width: 99%; overflow: auto;"}))
#     else:
#         temp.append(h)  
#     ++i

# %%
temp = bs.find_all("div", "ipsType_normal ipsType_richText ipsContained")

# %%
print(temp)

# %%
print(temp[0].text)
# Out:
# 	Кудри издавна считались особым элементом прически. Они вселяют невинность в образ, а также нежность и беззаботность. В некоторых случаях обольщения мужских сердец и глаз, без этого компонента попросту не обойтись. Однако многие девушки сталкиваются с вопросом: как их сделать правильно? Иногда достигнуть нужного результата не позволяет жесткость волоса. Профессиональный женский блог «Мюсли» сделал подборку самых эффективных методов.
# 	Методы завивки волос в кудри
#
#
# 	За всю историю, женская половина человечества накопила богатый опыт в завивке волос, создавая самые разные и причудливые рецепты. Некоторые из них канули в лета, а другие по-прежнему применяются и с большим успехом! Главное – следовать инструкциям, о которых подробно пишется на Mjusli.ru. Тогда и результат будет вполне эффектным. Самые популярные методы:
#
#
# ...

# %%
len(temp)
# Out:
# 35

# %%
for i in range(len(temp)):
    df.loc[ len(df.index )] = [temp[i].text]

# %%
df
# Out:
#                                                  text
# 0   \n\r\n\tКудри издавна считались особым элемент...
# 1   \n\n\tВсе время делаю себе кудри именно утюжко...
# 2             \n\n\tкрасиво то как, и я так хочу)\n\n
# 3   \n\n\tкрасиво, но волосы портятся будь здоров)...
# 4   \n\n\tЭто точно, от плоек и утюжков волосы сил...
# 5            \n\n\tУтюжок может попортить волосы.\n\n
# 6   \n\n\tДействительно волосы портятся из-за высо...
# 7   \n\n\tя так испортила утюжком волосы укладками...
# 8   \n\n\tутюжок должен быть специальный и для лок...
# 9   \n\n\tКудри утюжком я не делала, но вот волосы...
# 10  \n\n\tлегко, только нужен утюжек который не бу...
# 11                   \n\n\tОчень красиво и быстро\n\n
# 12  \n\n\n\t\tВ 27.08.2016 в 22:41, Ласковая сказа...
# 13  \n\n\tсколько раз пыталась сделать кудри утюжк...
# 14  \n\n\tУтюжком не получается тоже, обычная плой...
# 15    \n\n\tвот ни разу нормально не получилось (\n\n
# ...
