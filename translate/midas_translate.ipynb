# %%
import pandas as pd

# %%
train_midas = pd.read_csv("midas_train.csv")
val_midas = pd.read_csv("midas_dev.csv")

# %%
train_midas
# Out:
#                                                     text  \
# 0      how about another short piece of football news...
# 1      do you want to hear some fun facts about cats ...
# 2                        did you know that : yes > i did
# 3      what is the team that you are rooting for in m...
# 4      are you talking about a specific movie : not g...
# ...                                                  ...
# 10282  can you repeat the book name please : EMPTY > ...
# 10283  tell me more about it : that was very pretty >...
# 10284  the 1956 film the ten commandments with moses ...
# 10285                  of course we can chat : EMPTY > i
# 10286                                period : EMPTY > oh
#
#                 joint_labels
# 0      open_question_factual
# 1         pos_answer;command
# 2                 pos_answer
# 3                    opinion
# 4                 pos_answer
# ...                      ...
# 10282                opinion
# 10283                comment
# 10284             neg_answer
# 10285                abandon
# 10286                   hold
#
# [10287 rows x 2 columns]

# %%
val_midas
# Out:
#                                                    text           joint_labels
# 0               i think i heard wrong : EMPTY > top gun              statement
# 1     don't give up on me : EMPTY > i'm not giving u...              statement
# 2     do you mind tell me one more time : EMPTY > wh...  open_question_factual
# 3     can you repeat the book name please : EMPTY > ...              statement
# 4     do you prefer to watch movies in the theater o...                opinion
# ...                                                 ...                    ...
# 2587         do you want more like these : EMPTY > yeah     pos_answer;command
# 2588  do you want to tell me your name : EMPTY > i n...               nonsense
# 2589  fun : i like fun because you go to different p...                opinion
# 2590  i think i would like to be a sea sponge and li...           appreciation
# 2591  have you seen any movies recently : EMPTY > i ...                comment
#
# [2592 rows x 2 columns]

# %%
# import requests

IAM_TOKEN = 't1.9euelZqLm82NjIrNnpvIm4vMmM3Hze3rnpWaj8fGjZOVi53NyZDPj8uTmM7l8_c-BHdg-e8MJ0wW_d3z934ydGD57wwnTBb9zef1656VmpGNip2blI-czceZjsrNnIqO7_0.dm7XT-PyrGqgQfTmqeGi31IK9PffgoXXP0-uh-LqIQIMWdi5IwXow6LOF0jtQJDslVtBzeo_B2HsGH1xvceRDQ'
# folder_id = 'b1gd6fl14qcdr9pabjuv'
# target_language = 'ru'
# texts = val_midas.iloc[:100]["EN"].tolist()

# body = {
#     "targetLanguageCode": target_language,
#     "texts": texts,
#     "folderId": folder_id,
# }

# headers = {
#     "Content-Type": "application/json",
#     "Authorization": "Bearer {0}".format(IAM_TOKEN)
# }

# response = requests.post('https://translate.api.cloud.yandex.net/translate/v2/translate',
#     json = body,
#     headers = headers
# )

# print(response.text)

# %%
# [t["text"] for t in response.json()["translations"]]

# %%
# https://nikolaymatrosov.medium.com/%D0%BA%D0%B0%D0%BA-%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D1%8C%D1%81%D1%8F-translate-api-%D0%B2-yandex-cloud-27d9660c7b2d

import csv
import os
from typing import List

import requests

# API_KEY = os.environ["API_KEY"]


# В примере я использую только 2 языка.
# Полный список языков можно получить по инструкции https://cloud.yandex.ru/docs/translate/operations/list
class Lang:
    RU = "ru"
    EN = "en"


class Format:
    PLAIN_TEXT = "PLAIN_TEXT"
    HTML = "HTML"


def translate(texts: List[str], source: str, target: str) -> List[str]:
    # Сформируем заголовок запроса с ключем авторизации
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer {0}".format(IAM_TOKEN)
    }

    # Отправим запрос
    res = requests.post(
        "https://translate.api.cloud.yandex.net/translate/v2/translate",
        json={
            "sourceLanguageCode": source,
            "targetLanguageCode": target,
            "format": Format.PLAIN_TEXT,
            "texts": texts,
        },
        headers=headers)

    return [t["text"] for t in res.json()["translations"]]


# Переводить будем с русского на английский
# Задаем соответствующие значения переменным
source = Lang.EN
target = Lang.RU


def main():
    # Открываем на чтени исходный файл
    with open('midas_dev.csv') as input_csv, \
            open('midas_dev_ru.csv', 'w', newline='') as result_csv:  # и на запись файл с результатами
        # Задаем названия колонок в файле с переводами
        fieldnames = [source, target]
        # Инициализируем объект-писатель, передав в него названия колонок
        writer = csv.DictWriter(result_csv, fieldnames=fieldnames)
        # Так же инициализируем читателя
        reader = csv.DictReader(input_csv)
        # Запишем в файл заголовки колонок
        writer.writeheader()
        # А теперь построчно будем читать наш исходный файл
        i = 0
        for row in reader:
            text = row['text']
            # Переводить значение
            results = translate([text], source=source, target=target)
            # И записывать результат
            writer.writerow({source: text, target: results[0]})
            ++i
            if i == 2592:
                break


if __name__ == '__main__':
    main()

# %%
# https://nikolaymatrosov.medium.com/%D0%BA%D0%B0%D0%BA-%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D1%82%D1%8C%D1%81%D1%8F-translate-api-%D0%B2-yandex-cloud-27d9660c7b2d

import csv
import os
from typing import List

import requests

# API_KEY = os.environ["API_KEY"]


# В примере я использую только 2 языка.
# Полный список языков можно получить по инструкции https://cloud.yandex.ru/docs/translate/operations/list
class Lang:
    RU = "ru"
    EN = "en"


class Format:
    PLAIN_TEXT = "PLAIN_TEXT"
    HTML = "HTML"


def translate(texts: List[str], source: str, target: str) -> List[str]:
    # Сформируем заголовок запроса с ключем авторизации
    headers = {
        "Content-Type": "application/json",
        "Authorization": "Bearer {0}".format(IAM_TOKEN)
    }

    # Отправим запрос
    res = requests.post(
        "https://translate.api.cloud.yandex.net/translate/v2/translate",
        json={
            "sourceLanguageCode": source,
            "targetLanguageCode": target,
            "format": Format.PLAIN_TEXT,
            "texts": texts,
        },
        headers=headers)

    return [t["text"] for t in res.json()["translations"]]


# Переводить будем с русского на английский
# Задаем соответствующие значения переменным
source = Lang.EN
target = Lang.RU


def main():
    # Открываем на чтени исходный файл
    with open('midas_train.csv') as input_csv, \
            open('midas_train_ru.csv', 'w', newline='') as result_csv:  # и на запись файл с результатами
        # Задаем названия колонок в файле с переводами
        fieldnames = [source, target]
        # Инициализируем объект-писатель, передав в него названия колонок
        writer = csv.DictWriter(result_csv, fieldnames=fieldnames)
        # Так же инициализируем читателя
        reader = csv.DictReader(input_csv)
        # Запишем в файл заголовки колонок
        writer.writeheader()
        # А теперь построчно будем читать наш исходный файл
        i = 0
        for row in reader:
            text = row['text']
            # Переводить значение
            results = translate([text], source=source, target=target)
            # И записывать результат
            writer.writerow({source: text, target: results[0]})
            ++i
            if i == 10287:
                break


if __name__ == '__main__':
    main()
